// %% [markdown]
// # Exercício 01
// <p style="text-align:justify;">
// Crie um programa que armazene um vetor com as notas de dez alunos, calcule e imprima a média dessas notas e depois informe a quantidade de notas acima e abaixo da média calculada.
// </p>

// %%
//public class Atv04{
    //public static void main (String args[]){
        float[] notas = {7.0f, 6.5f, 8.0f, 9.0f, 4.5f, 9.8f, 7.7f, 5.8f, 9.5f, 10.0f};
        int acima=0, abaixo=0, i, j;
        double x=0, media;

        for(i=0; i<notas.length; i++) {
            x += notas[i];        
        }

        media = x / notas.length;

        for(j=0; j<notas.length; j++) {
            if(notas[j] >= media) {
                acima++;
            } else {
                abaixo++;
            }      
        }

        System.out.printf("A média das notas é: %.2f\n", media);
        System.out.printf("Abaixo da média total: %d \nAcima da média total: %d\n", abaixo, acima);
    //}
//}
// Out:
// A média das notas é: 7.78
// Abaixo da média total: 5
// Acima da média total: 5
// null

// %% [markdown]
// # Exercício 02
// <p style="text-align:justify;">
// Construa uma classe em Java que seja capaz de efetuar a leitura de uma matriz de valores reais de tamanho 3 x 3, calculando seu determinante.
// </p>

// %%
import java.util.Scanner;

//public class Atv04 {
    //public static void main(String[] args) {
        Scanner entrada = new Scanner(System.in);
        float[][] matriz = new float[3][3];
        float x;
        int i;

        for (i = 0; i < matriz.length; i++) {
            for (int j = 0; j < matriz.length; j++) {
                System.out.printf("Digite o elemento [%d] [%d]: \n", i, j);
                matriz[i][j] = entrada.nextFloat();
            }
        }

        entrada.close();

        x = matriz[0][0] * (matriz[1][1] * matriz[2][2] - matriz[1][2] * matriz[2][1])
                - matriz[0][1] * (matriz[1][0] * matriz[2][2] - matriz[1][2] * matriz[2][0])
                + matriz[0][2] * (matriz[1][0] * matriz[2][1] - matriz[1][1] * matriz[2][0]);
        System.out.println("O determinante da matriz é: " + x);
        
    //}
//}
// Out:
// Digite o elemento [0] [0]:
//  5
// Digite o elemento [0] [1]:
//  5
// Digite o elemento [0] [2]:
//  6
// Digite o elemento [1] [0]:
//  5
// Digite o elemento [1] [1]:
//  9
// Digite o elemento [1] [2]:
//  4
// Digite o elemento [2] [0]:
//  3
// Digite o elemento [2] [1]:
//  2
// Digite o elemento [2] [2]:
//  7
// O determinante da matriz é: 58.0
// null

// %% [markdown]
// # Exercício 03
// <p style="text-align:justify;">
// Faça uma classe contendo dois arrays do tipo inteiro, um chamado par e outro chamado ímpar. Cada array deve conter 10 elementos. A seguir, faça um laço de repetição com 10 iterações e que contenha internamente a geração randômica de números entre 1 e 20. Se o valor gerado for par, armazene no array chamado par, caso contrário, no array chamado impar. Ao final, apresente o conteúdo de cada um dos arrays.
// </p>

// %%
import java.util.Random;

//public class Atv04 {
    //public static void main(String[] args) {
        Random rand = new Random();
        int[] par = new int[10];
        int[] impar = new int[10];
        int contadorPar = 0, contadorImpar = 0, i, x;

        for (i = 0; i < 10; i++) {
            x = rand.nextInt(20)+1;
            
            if (x % 2 == 0) {
                par[contadorPar] = x;
                contadorPar++;
            } else {
                impar[contadorImpar] = x;
                contadorImpar++;
            }
        }

        System.out.println("Números pares: ");
        for (i = 0; i < par.length; i++) {
            System.out.printf("%d ", par[i]);
        }

        System.out.println("\nNúmeros ímpares: ");
        for (i = 0; i < impar.length; i++) {
            System.out.printf("%d ", impar[i]);
        }
        
    //}
//}
// Out:
// Números pares:
// 4 4 20 4 16 2 0 0 0 0
// Números ímpares:
// 17 19 11 19 0 0 0 0 0 0
// null

// %% [markdown]
// # Exercício 04
// <p style="text-align:justify;">
// Usando um array unidimensional de 10 elementos do tipo String, faça uma classe que simule a ocupação de um estacionamento de veículos. Considere que a posição do array corresponde ao número da vaga e para cada vaga é armazenada a placa do veículo que está estacionado. Sua classe deve conter um laço de repetição simulando um menu que controle a entrada e a saída dos veículos com as opções: 1-Entrada, 2-Saída e 3-Listar situação atual e 4-Encerrar o programa. Se o usuário escolher 1, solicite o número da vaga e a placa do veículo; se escolher 2, solicite o número da vaga que será liberada e armazene o valor branco na posição correspondente ao array; se escolher 3, liste a situação atual apresentando em tela todos os elementos do array; quando for 4, encerre o laço e o programa.
// </p>

// %%
import java.util.Scanner;

//public class Atv04 {
    //public static void main(String[] args) {
        Scanner entrada = new Scanner(System.in);
        String[] vagas = new String[10];
        boolean sair = true;
        int numeroVaga;

         while (sair) {
            System.out.println("\nMenu:");
            System.out.println("1 - Entrada");
            System.out.println("2 - Saída");
            System.out.println("3 - Listar situação atual");
            System.out.println("4 - Encerrar o programa");
            System.out.print("Escolha uma opção: ");
            int opcao = entrada.nextInt();

            if (opcao == 1) {
                System.out.print("Digite o número da vaga: ");
                numeroVaga = entrada.nextInt();
                entrada.nextLine(); // Limpar o buffer de entrada
                if (numeroVaga < vagas.length) {
                    if (vagas[numeroVaga] == null || vagas[numeroVaga].isEmpty()) {
                        System.out.print("Digite a placa do veículo: ");
                        String placa = entrada.nextLine();
                        vagas[numeroVaga] = placa;
                        System.out.println("Veículo estacionado na vaga " + numeroVaga);
                    } else {
                        System.out.println("Esta vaga já está ocupada.");
                    }
                } else {
                    System.out.println("Vaga inválida! Tente novamente.");
                }
            } else if (opcao == 2) {
                System.out.print("Digite o número da vaga que será liberada: ");
                numeroVaga = entrada.nextInt();

                if (numeroVaga < vagas.length) {
                    vagas[numeroVaga] = "";
                    System.out.println("Vaga " + numeroVaga + " liberada.");
                } else {
                    System.out.println("Vaga inválida! Tente novamente.");
                }
            } else if (opcao == 3) {
                System.out.println("\nSituação atual do estacionamento:");
                            for (int i = 0; i < vagas.length; i++) {
                    if (vagas[i] == null || vagas[i].isEmpty()) {
                        System.out.println("Vaga " + i + ": vazia");
                    } else {
                        System.out.println("Vaga " + i + ": " + vagas[i]);
                    }
                }
            } else if (opcao == 4) {
                sair = false;
            } else {
                System.out.println("Opção inválida! Tente novamente.");
            }
        }
    //}
//}
// Out:
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  1
// Digite o número da vaga:
//  5
// Digite a placa do veículo:
//  xxx
// Veículo estacionado na vaga 5
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  1
// Digite o número da vaga:
//  9
// Digite a placa do veículo:
//  yyy
// Veículo estacionado na vaga 9
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  2
// Digite o número da vaga que será liberada:
//  5
// Vaga 5 liberada.
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  3
// Situação atual do estacionamento:
// Vaga 0: vazia
// Vaga 1: vazia
// Vaga 2: vazia
// Vaga 3: vazia
// Vaga 4: vazia
// Vaga 5: vazia
// Vaga 6: vazia
// Vaga 7: vazia
// Vaga 8: vazia
// Vaga 9: yyy
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  4
// null

// %% [markdown]
// # Exercício 05
// <p style="text-align:justify;">
// Uma imagem é formada por pixels. Considere uma imagem com dimensão de 40 x 40 e faça uma classe que contenha um array bidimensional com essas dimensões. A seguir, para cada posição
// desse array bidimensional armazene um valor aleatório entre 0 e 255 (esses valores correspondem às tonalidades aplicadas sobre a imagem). Apresente em tela os 1600 valores gerados.
// </p>

// %%
import java.util.Random;

//public class Atv04 {
    //public static void main(String[] args) {
        Random rand = new Random();
        int[][] img = new int[40][40];
        int i, j;

        for (i = 0; i < 40; i++) {
            for (j = 0; j < 40; j++) {
                img[i][j] = rand.nextInt(256);
            }
        }

        System.out.println("Tonalidades aplicadas sobre a imagem:");
        for (i = 0; i < 40; i++) {
            for (j = 0; j < 40; j++) {
                System.out.printf("%d ", img[i][j]);
            }
            System.out.printf("\n");
        }
    //}
//}
// Out:
// Tonalidades aplicadas sobre a imagem:
// 152 19 95 192 228 40 70 145 156 73 141 212 118 82 143 254 225 186 223 237 189 138 100 201 92 101 32 80 215 181 184 28 50 223 86 147 149 189 51 159
// 53 253 233 15 181 45 160 97 188 200 57 198 164 237 22 116 166 105 70 220 138 138 71 240 2 23 5 57 180 90 81 224 215 229 81 195 54 206 106 245
// 102 165 253 93 220 3 29 10 42 149 92 253 110 100 103 32 236 191 188 64 149 219 6 250 36 62 215 77 168 122 74 109 9 173 192 78 6 31 114 81
// 173 21 248 116 158 200 19 51 169 129 148 61 207 172 103 11 244 100 204 190 184 66 84 207 197 129 80 191 183 124 234 39 98 224 171 210 231 111 178 91
// 50 184 132 217 238 146 138 106 116 225 41 71 206 96 251 76 125 120 198 216 215 16 252 145 111 247 236 163 62 134 197 232 8 223 131 89 142 47 218 162
// 51 115 35 194 92 233 226 234 183 173 203 231 150 93 214 65 172 227 104 227 1 117 3 207 215 233 33 4 96 185 12 39 171 164 90 183 42 90 102 145
// 30 61 168 186 158 174 61 35 24 253 53 68 122 199 104 218 234 250 33 3 151 103 22 80 203 100 45 121 55 112 80 241 19 35 148 157 225 84 206 89
// 139 245 98 185 52 160 180 233 2 7 158 36 64 16 199 2 238 32 166 202 156 222 64 205 223 53 193 132 147 74 252 64 33 37 107 217 143 76 217 220
// 0 219 37 18 0 133 93 165 212 232 149 147 249 85 68 20 250 212 173 237 210 221 110 235 214 35 13 130 38 92 224 140 234 2 86 114 188 25 192 207
// 14 20 63 32 237 96 31 104 235 176 50 225 110 190 40 160 231 28 249 88 122 229 183 110 197 21 135 119 173 229 190 40 103 244 55 112 21 147 202 119
// 68 62 216 173 100 15 6 204 102 113 236 130 101 70 120 77 210 241 229 87 88 57 224 21 197 249 208 14 21 150 155 180 52 78 232 196 121 225 8 251
// 129 27 168 64 216 11 154 161 149 75 152 56 243 202 81 156 2 245 186 251 43 125 160 237 48 67 190 73 132 169 236 71 16 86 70 198 96 98 150 2
// 70 53 101 2 176 14 78 253 64 206 56 32 197 251 178 66 61 120 226 209 222 43 159 199 207 10 117 231 247 169 128 61 10 248 85 165 117 85 178 150
// 49 65 119 207 173 229 175 237 73 63 86 200 126 89 252 123 214 129 15 17 156 140 11 128 150 226 221 70 119 12 9 121 224 40 139 215 46 144 107 121
// 38 20 182 6 58 164 90 52 208 220 152 14 51 57 131 39 155 115 1 217 69 195 187 69 108 194 141 152 205 126 210 195 150 98 137 24 180 74 110 249
// 93 211 22 21 48 46 52 165 149 105 255 175 184 89 195 184 64 132 81 176 8 228 184 106 249 128 92 165 109 14 250 105 58 48 212 174 139 18 200 6
// 114 61 248 107 72 233 124 129 64 233 72 176 157 130 218 10 10 68 27 151 135 239 212 157 157 159 120 219 124 47 14 152 144 121 24 224 87 231 249 207
// 118 209 255 95 220 83 149 229 58 198 45 91 167 79 186 1 73 47 8 16 125 250 183 38 146 128 197 107 210 239 118 24 176 217 187 7 128 144 201 92
// 40 192 207 222 139 15 113 177 221 44 73 124 31 45 132 86 146 44 72 38 207 208 82 168 157 68 188 84 143 139 111 207 170 22 47 172 189 33 192 203
// 217 173 251 24 26 254 100 161 41 222 123 156 134 71 26 92 221 220 158 62 203 214 93 79 246 7 205 197 248 14 182 70 224 114 132 12 51 232 3 110
// 215 107 249 87 55 242 50 47 146 101 90 124 35 78 194 184 94 122 153 153 179 245 194 195 178 134 106 216 98 132 75 194 53 114 74 236 122 241 124 238
// 229 13 109 12 179 109 204 162 40 251 77 178 87 122 24 213 92 28 61 209 196 253 80 15 145 151 150 232 122 199 158 190 0 95 151 64 199 120 0 175
// 2 209 152 142 149 40 242 82 37 63 87 100 216 153 59 168 88 28 85 47 148 235 82 206 12 72 199 221 113 2 201 183 137 196 119 32 117 213 20 23
// 176 192 8 176 133 211 149 70 222 110 128 71 225 134 76 206 158 143 155 200 26 65 175 85 108 2 90 134 127 103 42 204 220 231 150 224 97 140 142 50
// 251 4 200 20 44 247 44 166 32 95 12 184 171 184 198 71 170 169 139 102 148 162 120 39 213 106 173 224 205 210 179 136 7 53 68 118 204 121 4 223
// 181 82 181 126 180 188 204 56 101 120 79 120 240 93 83 42 236 47 159 210 83 187 149 28 168 101 46 98 235 143 240 88 23 128 59 88 32 71 117 89
// 208 37 76 196 214 176 243 221 149 78 21 219 205 214 219 118 253 31 18 223 180 153 57 169 231 22 90 204 242 162 111 99 182 213 177 0 94 157 17 10
// 47 212 151 180 214 172 80 109 164 146 10 114 235 35 146 205 254 236 14 150 139 102 141 114 27 64 158 170 245 163 218 110 253 211 119 143 7 224 88 225
// 20 242 115 117 110 108 224 135 48 169 99 30 249 80 173 55 116 237 75 68 0 208 173 236 213 52 162 197 120 89 93 18 208 62 169 228 27 150 18 0
// 18 226 93 3 207 106 200 17 248 37 115 66 43 193 52 66 18 202 200 209 10 11 167 17 252 238 62 7 167 29 143 40 43 200 141 37 3 11 183 125
// 140 249 127 35 226 29 65 174 53 51 112 27 4 203 43 206 192 3 58 156 217 244 178 76 45 209 185 206 92 41 40 97 199 251 240 57 107 255 6 28
// 198 243 101 11 103 192 198 72 6 249 210 220 170 220 213 118 152 238 52 86 226 131 66 189 143 19 140 156 54 215 29 75 233 91 10 241 157 231 109 86
// 25 41 40 251 215 115 115 249 100 196 74 227 219 31 124 46 206 251 207 202 201 70 218 110 45 183 9 47 232 40 201 140 150 2 136 139 88 115 211 201
// 28 100 84 172 206 154 36 212 193 232 21 117 224 101 120 212 27 55 229 60 24 133 202 190 50 175 168 85 60 171 205 9 241 20 238 78 19 209 27 24
// 97 200 12 1 47 8 141 251 239 43 243 234 14 221 168 164 230 167 106 22 113 38 24 83 75 142 199 172 105 96 57 199 98 180 229 40 76 113 87 180
// 29 245 41 124 141 194 211 23 232 145 153 175 253 16 173 70 81 85 154 220 21 112 237 15 79 3 197 79 76 1 85 179 254 78 90 17 196 228 87 103
// 2 33 46 65 14 202 187 202 233 126 193 161 10 94 132 218 59 121 248 9 122 81 181 40 62 69 70 203 54 147 50 90 193 76 146 180 135 179 171 145
// 175 138 241 247 158 187 170 2 142 40 100 72 198 74 14 207 134 137 24 86 88 215 20 58 255 104 100 45 101 39 180 89 108 192 144 34 67 21 146 229
// 106 112 191 179 79 177 241 255 217 119 189 47 133 153 28 139 68 172 60 241 153 55 134 105 129 141 44 209 199 36 92 214 41 161 4 180
// IOPub message rate exceeded.
// The Jupyter server will temporarily stop sending output
// to the client in order to avoid crashing it.
// To change this limit, set the config variable
// `--ServerApp.iopub_msg_rate_limit`.
//
// Current values:
// ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
// ServerApp.rate_limit_window=3.0 (secs)
